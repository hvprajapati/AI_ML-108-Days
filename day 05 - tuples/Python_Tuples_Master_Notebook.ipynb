# %% [markdown]
# # Python Tuples Master Notebook
#
# Complete beginner to advanced Tuple notebook with explanations and examples.

# %% [markdown]
# # Introduction to Tuples
#
# ## What is a Tuple?
# A tuple is an ordered and immutable collection of elements.

# %%
t=(10,20,30)
print(t)
# Out:
# (10, 20, 30)

# %% [markdown]
# # Creating Tuples
#
# ## Creating Tuples
# Different ways to create tuples.

# %%
t1=()
t2=tuple()
t3=(1,2,3)
t4=('Python',22,True)
print(t1,t2,t3,t4)
# Out:
# () () (1, 2, 3) ('Python', 22, True)

# %% [markdown]
# # Single Element Tuple
#
# ## Single Element Tuple
# The comma creates the tuple.

# %%
t=(10,)
print(type(t))
# Out:
# <class 'tuple'>

# %% [markdown]
# # Tuple Packing
#
# ## Tuple Packing
# Python automatically packs values into tuples.

# %%
t=10,20,30
print(t)
# Out:
# (10, 20, 30)

# %% [markdown]
# # Tuple Unpacking
#
# ## Tuple Unpacking

# %%
t=(10,20,30)
a,b,c=t
print(a,b,c)
# Out:
# 10 20 30

# %% [markdown]
# # Extended Unpacking
#
# ## Extended Unpacking

# %%
t=(10,20,30,40,50)
a,*mid,b=t
print(a)
print(mid)
print(b)

# %% [markdown]
# # Indexing
#
# ## Indexing
# Positive and negative indexing.

# %%
t=(100,200,300,400)
print(t[0])
print(t[-1])
# Out:
# 100
# 400

# %% [markdown]
# # Slicing
#
# ## Slicing

# %%
t=(10,20,30,40,50)
print(t[1:4])
print(t[::-1])
# Out:
# (20, 30, 40)
# (50, 40, 30, 20, 10)

# %% [markdown]
# # Immutability
#
# ## Tuples are Immutable

# %%
t=(10,20,30)
t[1]=999
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 t=(10,20,30)
# ----> 2 t[1]=999
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Traversing Tuples
#
# ## Traversing Tuples

# %%
t=(10,20,30)
for item in t:
    print(item)
# Out:
# 10
# 20
# 30

# %% [markdown]
# # Concatenation
#
# ## Tuple Concatenation

# %%
a=(1,2)
b=(3,4)
print(a+b)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# # Repetition
#
# ## Tuple Repetition

# %%
print((1,2)*3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %% [markdown]
# # Membership
#
# ## Membership Operators

# %%
print(20 in (10,20,30))
# Out:
# True

# %% [markdown]
# # count() Method
#
# ## count()

# %%
t=(1,1,1,2,2,3)
print(t.count(1))
# Out:
# 3

# %% [markdown]
# # index() Method
#
# ## index()

# %%
t=(10,20,30)
print(t.index(20))
# Out:
# 1

# %% [markdown]
# # Built-in Functions
#
# ## Built-in Functions

# %%
t=(10,20,30,40)
print(len(t))
print(max(t))
print(min(t))
print(sum(t))
# Out:
# 4
# 40
# 10
# 100

# %% [markdown]
# # Nested Tuples
#
# ## Nested Tuples

# %%
t=((1,2),(3,4),(5,6))
print(t[1][0])
# Out:
# 3

# %%
t=((1,2,3,(9,8)),(4,5,6),(7,8,9), "python",[10,20,30])
print(t[0][3][1])
# Out:
# 8

# %% [markdown]
# # Tuple vs List
#
# ## Tuple vs List
# Compare mutability, memory, speed.

# %%
# Theory Section

# %% [markdown]
# # Memory Efficiency
#
# ## Memory Efficiency

# %%
import sys
lst=[1,2,3,4,5]
tup=(1,2,3,4,5)
print(sys.getsizeof(lst))
print(sys.getsizeof(tup))
# Out:
# 104
# 80

# %% [markdown]
# # Hashability
#
# ## Tuple as Dictionary Key

# %%
t=(1,2,3)
d={t:'Python'}
print(d)

# %% [markdown]
# # Variable Swapping
#
# ## Swapping Variables

# %%
a=10
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %% [markdown]
# # Returning Multiple Values
#
# ## Function Returning Tuple

# %%
def student():
    return 'Hardik',22,'Ahmedabad'
print(student())
# Out:
# ('Hardik', 22, 'Ahmedabad')

# %% [markdown]
# # Reverse Tuple
#
# ## Reverse Tuple

# %%
t=(1,2,3,4)
print(t[::-1])
# Out:
# (4, 3, 2, 1)

# %% [markdown]
# # Convert List to Tuple
#
# ## List to Tuple

# %%
lst=[1,2,3]
print(tuple(lst))
# Out:
# (1, 2, 3)

# %% [markdown]
# # Convert Tuple to List
#
# ## Tuple to List

# %%
t=(1,2,3)
print(list(t))
# Out:
# [1, 2, 3]

# %% [markdown]
# # Frequency Counter
#
# ## Frequency Counter

# %%
t=(1,1,2,2,2,3)
freq={}
for item in t:
    freq[item]=freq.get(item,0)+1
print(freq)
# Out:
# {1: 2, 2: 3, 3: 1}

# %% [markdown]
# # Largest Element
#
# ## Largest Element

# %%
t=(10,50,20,90)
print(max(t))
# Out:
# 90

# %% [markdown]
# # Common Errors
#
# ## Common Errors
# Forgetting comma in single-element tuple.
# Trying to modify tuples.
