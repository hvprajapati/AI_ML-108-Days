# %% [markdown]
# # 📘 Pandas Masterclass – Part 1
# # Foundations of Pandas (Beginner → Intermediate)
#
# This notebook introduces Pandas from absolute basics.
#
# ## 📊 About the Dataset
#
# To make this notebook completely self-contained, we will **generate our own realistic dataset** and save it as `employees.csv`.
#
# This means you don't need to download anything from the internet.

# %% [markdown]
# ## 1. Installing & Importing Pandas

# %%
# pip install pandas

# Import Pandas with standard alias pd
import pandas as pd
# Import NumPy with standard alias np
import numpy as np

print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# ## 2. Create a Custom Dataset

# %%
import pandas as pd

# Create a sample employee dataset
df = pd.DataFrame({
    "EmployeeID": [1001, 1002, 1003, 1004, 1005],
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Department": ["IT", "HR", "Finance", "Sales", "Marketing"],
    "Age": [25, 30, 28, 35, 27],
    "Salary": [60000, 50000, 75000, 80000, 65000],
    "Experience": [2, 5, 4, 8, 3],
    "Rating": [4.5, 3.8, 4.7, 4.2, 4.9]
})

# Save the DataFrame as a CSV file
df.to_csv("employees.csv", index=False)

print("employees.csv created successfully!")
print(df)
# Out:
# employees.csv created successfully!
#    EmployeeID     Name Department  Age  Salary  Experience  Rating
# 0        1001    Alice         IT   25   60000           2     4.5
# 1        1002      Bob         HR   30   50000           5     3.8
# 2        1003  Charlie    Finance   28   75000           4     4.7
# 3        1004    David      Sales   35   80000           8     4.2
# 4        1005     Emma  Marketing   27   65000           3     4.9

# %% [markdown]
# From now on, every example in this notebook uses **employees.csv** that you just created.
#
# You can also replace it later with any real dataset.

# %% [markdown]
# ## 3. Reading CSV Files

# %%
# Load data from a CSV file into a DataFrame
df = pd.read_csv("employees.csv")

# Display first 5 rows of the DataFrame
print(df.head())
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience  Rating
# 0        1001    Alice         IT   25   60000           2     4.5
# 1        1002      Bob         HR   30   50000           5     3.8
# 2        1003  Charlie    Finance   28   75000           4     4.7
# 3        1004    David      Sales   35   80000           8     4.2
# 4        1005     Emma  Marketing   27   65000           3     4.9

# %% [markdown]
# ## 4. Understanding DataFrames & Series

# %%
print(type(df))
print(type(df["Salary"]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## 5. Basic Inspection

# %%
# Display first 5 rows of the DataFrame
print(df.head())
# Display last 5 rows of the DataFrame
print(df.tail())
print(df.sample(5))
# Print array shape (rows, columns)
print("*"*50)
# Show DataFrame dimensions (rows, columns)
print(df.shape)

print("*"*50)

# Show all column names
print(df.columns)
print("*"*50)


# Print data type of array elements
print("*"*50)

# Show data type of each column
print(df.dtypes)
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience  Rating
# 0        1001    Alice         IT   25   60000           2     4.5
# 1        1002      Bob         HR   30   50000           5     3.8
# 2        1003  Charlie    Finance   28   75000           4     4.7
# 3        1004    David      Sales   35   80000           8     4.2
# 4        1005     Emma  Marketing   27   65000           3     4.9
#    EmployeeID     Name Department  Age  Salary  Experience  Rating
# 0        1001    Alice         IT   25   60000           2     4.5
# 1        1002      Bob         HR   30   50000           5     3.8
# 2        1003  Charlie    Finance   28   75000           4     4.7
# 3        1004    David      Sales   35   80000           8     4.2
# 4        1005     Emma  Marketing   27   65000           3     4.9
#    EmployeeID     Name Department  Age  Salary  Experience  Rating
# 3        1004    David      Sales   35   80000           8     4.2
# ...

# %%
print(df.dtypes)
# Out:
# EmployeeID      int64
# Name           object
# Department     object
# Age             int64
# Salary          int64
# Experience      int64
# Rating        float64
# dtype: object

# %% [markdown]
# ## 6. Dataset Information

# %%
# Show column names, data types, and non-null counts
# print(df.info())
print(df.describe(include='all'))
# Out:
#          EmployeeID   Name Department        Age        Salary  Experience  \
# count      5.000000      5          5   5.000000      5.000000    5.000000
# unique          NaN      5          5        NaN           NaN         NaN
# top             NaN  Alice         IT        NaN           NaN         NaN
# freq            NaN      1          1        NaN           NaN         NaN
# mean    1003.000000    NaN        NaN  29.000000  66000.000000    4.400000
# std        1.581139    NaN        NaN   3.807887  11937.336386    2.302173
# min     1001.000000    NaN        NaN  25.000000  50000.000000    2.000000
# 25%     1002.000000    NaN        NaN  27.000000  60000.000000    3.000000
# 50%     1003.000000    NaN        NaN  28.000000  65000.000000    4.000000
# 75%     1004.000000    NaN        NaN  30.000000  75000.000000    5.000000
# max     1005.000000    NaN        NaN  35.000000  80000.000000    8.000000
#
#           Rating
# count   5.000000
# unique       NaN
# ...

# %% [markdown]
# ## 7. Selecting Data

# %%
# print(df["Name"])
print(df[["Name","Salary"]])
# Out:
#       Name  Salary
# 0    Alice   60000
# 1      Bob   50000
# 2  Charlie   75000
# 3    David   80000
# 4     Emma   65000

# %%
# Select rows/columns by label name
# print(df.loc[0])
# Select rows/columns by label name
print(df.iloc[0:4,0:2])
# Out:
#    EmployeeID     Name
# 0        1001    Alice
# 1        1002      Bob
# 2        1003  Charlie
# 3        1004    David

# %%
# Select rows/columns by integer position
print(df.iloc[0])
# Select rows/columns by integer position
print(df.iloc[0:5,1:4])
# Out:
#       Name Department  Age
# 0    Alice         IT   25
# 1      Bob         HR   30
# 2  Charlie    Finance   28
# 3    David      Sales   35
# 4     Emma  Marketing   27

# %% [markdown]
# ## 8. Adding New Columns

# %%
df["Bonus"] = df["Salary"] * 0.10
df["TotalSalary"] = df["Salary"] + df["Bonus"]

# Display first 5 rows of the DataFrame
print(df.head())
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience  Rating   Bonus  \
# 0        1001    Alice         IT   25   60000           2     4.5  6000.0
# 1        1002      Bob         HR   30   50000           5     3.8  5000.0
# 2        1003  Charlie    Finance   28   75000           4     4.7  7500.0
# 3        1004    David      Sales   35   80000           8     4.2  8000.0
# 4        1005     Emma  Marketing   27   65000           3     4.9  6500.0
#
#    TotalSalary
# 0      66000.0
# 1      55000.0
# 2      82500.0
# 3      88000.0
# 4      71500.0

# %% [markdown]
# ## 9. Renaming Columns

# %%
# Rename columns or index labels
df = df.rename(columns={"Rating":"PerformanceRating"})
# Show all column names
print(df.columns)
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Salary', 'Experience',
#        'PerformanceRating', 'Bonus', 'TotalSalary'],
#       dtype='object')

# %% [markdown]
# ## 10. Dropping Columns

# %%
# Drop specified rows from DataFrame
temp = df.drop(columns=["TotalSalary"])
# Display first 5 rows of the DataFrame
print(temp.head())
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience  PerformanceRating  \
# 0        1001    Alice         IT   25   60000           2                4.5
# 1        1002      Bob         HR   30   50000           5                3.8
# 2        1003  Charlie    Finance   28   75000           4                4.7
# 3        1004    David      Sales   35   80000           8                4.2
# 4        1005     Emma  Marketing   27   65000           3                4.9
#
#     Bonus
# 0  6000.0
# 1  5000.0
# 2  7500.0
# 3  8000.0
# 4  6500.0

# %% [markdown]
# ## 11. Sorting Data

# %%
# Display first 5 rows of the DataFrame
# print(df.sort_values("Salary").head())
# Display first 5 rows of the DataFrame
print(df.sort_values("Salary",ascending=False).head())
# Out:
#    EmployeeID     Name Department  Age  Salary  Experience  PerformanceRating  \
# 3        1004    David      Sales   35   80000           8                4.2
# 2        1003  Charlie    Finance   28   75000           4                4.7
# 4        1005     Emma  Marketing   27   65000           3                4.9
# 0        1001    Alice         IT   25   60000           2                4.5
# 1        1002      Bob         HR   30   50000           5                3.8
#
#     Bonus  TotalSalary
# 3  8000.0      88000.0
# 2  7500.0      82500.0
# 4  6500.0      71500.0
# 0  6000.0      66000.0
# 1  5000.0      55000.0

# %% [markdown]
# ## 12. Filtering Data

# %%
# high_salary = df[df["Salary"] > 50000]
# print(high_salary)

it_staff = df[df["Department"]=="IT"]
print(it_staff)
# Out:
#    EmployeeID   Name Department  Age  Salary  Experience  PerformanceRating  \
# 0        1001  Alice         IT   25   60000           2                4.5
#
#     Bonus  TotalSalary
# 0  6000.0      66000.0

# %% [markdown]
# ## 13. Value Counts

# %%
# Count unique values in a column
print(df["Salary"].value_counts())
# Out:
# Salary
# 60000    1
# 50000    1
# 75000    1
# 80000    1
# 65000    1
# Name: count, dtype: int64

# %% [markdown]
# ## 14. Mini Project - HR Dashboard

# %%
# Calculate the mean (average) of array elements
print("Average Salary:", df["Salary"].mean())
# Find the maximum value in the array
print("Highest Salary:", df["Salary"].max())
# Find the minimum value in the array
print("Lowest Salary:", df["Salary"].min())
print("\nDepartment Counts")
print(df["Department"].value_counts())

# %% [markdown]
# ## 15. Practice Exercises
#
# 1. Show only employees older than 30.
# 2. Find employees in Finance.
# 3. Sort by Experience.
# 4. Show the top 5 highest salaries.
# 5. Add a Tax column (5% of salary).
# 6. Rename EmployeeID to EmpID.
# 7. Remove the Bonus column.
# 8. Count employees in each department.

# %% [markdown]
# ## 16. Interview Questions
#
# 1. What is Pandas?
# 2. Difference between Series and DataFrame?
# 3. Difference between `loc` and `iloc`?
# 4. Difference between `head()` and `tail()`?
# 5. What does `describe()` do?
# 6. How do you filter rows?

# %% [markdown]
# # 🎉 Summary
#
# You learned:
#
# - Creating a realistic dataset
# - Reading CSV files
# - Series vs DataFrame
# - Inspecting data
# - Selecting rows & columns
# - `loc` and `iloc`
# - Adding, renaming and dropping columns
# - Sorting
# - Filtering
# - Basic analytics
#
# ➡️ **Next Notebook:** Missing values, duplicate handling, string operations, grouping, aggregation, merging, joining, concatenation and pivot tables.
