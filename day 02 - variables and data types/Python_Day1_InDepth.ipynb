# %% [markdown]
# # Python Day 1 - Foundations (In-Depth)
# Designed for absolute beginners to strong Python fundamentals.

# %% [markdown]
# ## Agenda
# 1. What is Python
# 2. Python Execution Model
# 3. Variables
# 4. Data Types
# 5. Input/Output
# 6. Operators
# 7. Type Conversion
# 8. Strings
# 9. Practice Exercises
# 10. Mini Project

# %% [markdown]
# ## 1. What is Python?
# Python is an interpreted, high-level, general-purpose programming language.

# %%
print('Hello World')

# %% [markdown]
# ## Variables
# Variables are labels pointing to objects in memory.

# %%
name='Hardik'
age=22
height=169.5
is_student=True
print(name, age, height, is_student)

# %% [markdown]
# ## Data Types

# %%
x=10
print(type(x))
y=10.5
print(type(y))
name='Python'
print(type(name))

# %% [markdown]
# ## Input and Output

# %%
# name=input('Enter name: ')
# print('Hello',name)

# %% [markdown]
# ## Operators

# %%
a=10
b=3
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# ## Type Conversion

# %%
num='100'
num=int(num)
print(num+50)
# Out:
# 150

# %% [markdown]
# ## Strings Deep Dive

# %%
text='Python'
print(text[0])
print(text[-1])
print(text[0:4])
print(text.upper())
print(len(text))

# %% [markdown]
# ## Practice Questions
# 1. Swap two numbers
# 2. Calculate area of circle
# 3. Convert Celsius to Fahrenheit
# 4. Reverse a string
# 5. Find datatype of variables

# %% [markdown]
# ## Mini Project - Student Information System

# %%
name='Hardik'
age=22
course='Data Science'
print(f'Name: {name}')
print(f'Age: {age}')
print(f'Course: {course}')

# %% [markdown]
# ## TYPES
# | Type     | Example  |
# | -------- | -------- |
# | int      | 10       |
# | float    | 10.5     |
# | complex  | 2+3j     |
# | bool     | True     |
# | str      | "Python" |
# | list     | [1,2,3]  |
# | tuple    | (1,2,3)  |
# | set      | {1,2,3}  |
# | dict     | {"a":1}  |
# | NoneType | None     |
